# %%
import pandas as pd 
import numpy as np  
import plotly.express as px 
import matplotlib.pyplot as plt
import seaborn as sb 
import plotly.subplots as sp
import plotly.graph_objs as go 
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import SelectKBest
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report
from sklearn.ensemble import RandomForestClassifier

# %%
# Importing dataset
df=pd.read_csv('/kaggle/input/mental-disorder-classification/Dataset-Mental-Disorders.csv',index_col='Patient Number')
df.head(2)
# Out:
#                 Sadness Euphoric  Exhausted Sleep dissorder Mood Swing  \
# Patient Number
# Patiant-01      Usually   Seldom  Sometimes       Sometimes        YES
# Patiant-02      Usually   Seldom    Usually       Sometimes         NO
#
#                Suicidal thoughts Anorxia Authority Respect Try-Explanation  \
# Patient Number
# Patiant-01                  YES       NO                NO             YES
# Patiant-02                   YES      NO                NO              NO
#
#                Aggressive Response Ignore & Move-On Nervous Break-down  \
# Patient Number
# Patiant-01                      NO               NO                YES
# Patiant-02                      NO               NO                 NO
#
#                Admit Mistakes Overthinking Sexual Activity Concentration  \
# Patient Number
# Patiant-01                YES          YES       3 From 10     3 From 10
# Patiant-02                 NO           NO       4 From 10     2 From 10
#
#                 Optimisim Expert Diagnose
# Patient Number
# Patiant-01      4 From 10  Bipolar Type-2
# Patiant-02      5 From 10      Depression

# %%
#summery of dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 120 entries, Patiant-01 to Patiant-120
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Sadness              120 non-null    object
#  1   Euphoric             120 non-null    object
#  2   Exhausted            120 non-null    object
#  3   Sleep dissorder      120 non-null    object
#  4   Mood Swing           120 non-null    object
#  5   Suicidal thoughts    120 non-null    object
#  6   Anorxia              120 non-null    object
#  7   Authority Respect    120 non-null    object
#  8   Try-Explanation      120 non-null    object
#  9   Aggressive Response  120 non-null    object
#  10  Ignore & Move-On     120 non-null    object
#  11  Nervous Break-down   120 non-null    object
#  12  Admit Mistakes       120 non-null    object
#  13  Overthinking         120 non-null    object
#  14  Sexual Activity      120 non-null    object
#  15  Concentration        120 non-null    object
#  16  Optimisim            120 non-null    object
#  17  Expert Diagnose      120 non-null    object
# dtypes: object(18)
# memory usage: 17.8+ KB

# %%
# unique values in each columns
for i in df.columns:
    print(f"{i}: {df[i].unique()}")
# Out:
# Sadness: ['Usually' 'Sometimes' 'Seldom' 'Most-Often']
# Euphoric: ['Seldom' 'Most-Often' 'Usually' 'Sometimes']
# Exhausted: ['Sometimes' 'Usually' 'Seldom' 'Most-Often']
# Sleep dissorder: ['Sometimes' 'Most-Often' 'Usually' 'Seldom']
# Mood Swing: ['YES' 'NO']
# Suicidal thoughts: ['YES ' 'YES' 'NO']
# Anorxia: ['NO' 'YES']
# Authority Respect: ['NO' 'YES']
# Try-Explanation: ['YES' 'NO']
# Aggressive Response: ['NO' 'YES']
# Ignore & Move-On: ['NO' 'YES']
# Nervous Break-down: ['YES' 'NO']
# Admit Mistakes: ['YES' 'NO']
# Overthinking: ['YES' 'NO']
# Sexual Activity: ['3 From 10' '4 From 10' '6 From 10' '5 From 10' '7 From 10' '8 From 10'
#  '9 From 10' '2 From 10' '1 From 10']
# Concentration: ['3 From 10' '2 From 10' '5 From 10' '4 From 10' '7 From 10' '6 From 10'
#  '1 From 10' '8 From 10']
# Optimisim: ['4 From 10' '5 From 10' '7 From 10' '2 From 10' '6 From 10' '9 From 10'
#  '3 From 10' '8 From 10' '1 From 10']
# Expert Diagnose: ['Bipolar Type-2' 'Depression' 'Bipolar Type-1' 'Normal']

# %%
# merging same values in 'Suicidal thoughts' column
df.loc[df[df['Suicidal thoughts']=='YES ']['Suicidal thoughts'].index[0],'Suicidal thoughts']='YES'

# %%
# drawing plot for each columns

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)# Suppress FutureWarning messages

for i in df.columns[4:-4]:
    table=pd.pivot_table(df,index='Expert Diagnose',aggfunc='count',columns=i,values='Optimisim')
    plot=px.bar(table,color_discrete_sequence=['red','green'],labels={'value':'Count'},title=f"Having {i} in each groups")
    plot.show()
    
    
dic=dict()
values=['blue','purple','black','orange','red','skyblue','green']
keys=df.columns[:-1].drop(df.columns[4:-4])
for i in range(len(keys)):
       dic.update({keys[i]:values[i]})


for i in range(7):
   
      plott=px.density_heatmap(data_frame=df,x='Expert Diagnose',y=list(dic)[i],color_continuous_scale=['white',list(dic.values())[i]])
      plott.update_layout(go.Layout(yaxis={'categoryarray':df[list(dic)[i]].sort_values(inplace=False).unique(),'title':list(dic)[i]},xaxis={'categoryarray':['Bipolar Type-1','Bipolar Type-2','Depression','Normal']},hovermode='closest'))
      plott.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.27.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="cb882e7b-6f83-46fa-927d-b0cc8a259a1f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cb882e7b-6f83-46fa-927d-b0cc8a259a1f")) {                    Plotly.newPlot(                        "cb882e7b-6f83-46fa-927d-b0cc8a259a1f",                        [{"alignmentgroup":"True","hovertemplate":"Mood Swing=NO\u003cbr\u003eExpert Diagnose=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"NO","marker":{"color":"red","pattern":{"shape":""}},"name":"NO","offsetgroup":"NO","orientation":"v","showlegend":true,"textposition":"auto","x":["Bipolar Type-1","Bipolar Type-2","Depression","Normal"],"xaxis":"x","y":[3.0,null,31.0,29.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Mood Swing=YES\u003cbr\u003eExpert Diagnose=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"YES","marker":{"color":"green","pattern":{"shape":""}},"name":"YES","offsetgroup":"YES","orientation":"v","showlegend":true,"textposition":"auto","x":["Bipolar Type-1","Bipolar Type-2","Depression","Normal"],"xaxis":"x","y":[25.0,31.0,null,1.0],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"ty ...
# <div>                            <div id="0f4f0798-ce5c-4061-a39f-8c621712fc15" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0f4f0798-ce5c-4061-a39f-8c621712fc15")) {                    Plotly.newPlot(                        "0f4f0798-ce5c-4061-a39f-8c621712fc15",                        [{"alignmentgroup":"True","hovertemplate":"Suicidal thoughts=NO\u003cbr\u003eExpert Diagnose=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"NO","marker":{"color":"red","pattern":{"shape":""}},"name":"NO","offsetgroup":"NO","orientation":"v","showlegend":true,"textposition":"auto","x":["Bipolar Type-1","Bipolar Type-2","Depression","Normal"],"xaxis":"x","y":[17,8,10,28],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Suicidal thoughts=YES\u003cbr\u003eExpert Diagnose=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"YES","marker":{"color":"green","pattern":{"shape":""}},"name":"YES","offsetgroup":"YES","orientation":"v","showlegend":true,"textposition":"auto","x":["Bipolar Type-1","Bipolar Type-2","Depression","Normal"],"xaxis":"x","y":[11,23,21,2],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type ...
# <div>                            <div id="51563dcd-b19f-4e2e-9668-3e74e79811d7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("51563dcd-b19f-4e2e-9668-3e74e79811d7")) {                    Plotly.newPlot(                        "51563dcd-b19f-4e2e-9668-3e74e79811d7",                        [{"alignmentgroup":"True","hovertemplate":"Anorxia=NO\u003cbr\u003eExpert Diagnose=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"NO","marker":{"color":"red","pattern":{"shape":""}},"name":"NO","offsetgroup":"NO","orientation":"v","showlegend":true,"textposition":"auto","x":["Bipolar Type-1","Bipolar Type-2","Depression","Normal"],"xaxis":"x","y":[13,17,21,23],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Anorxia=YES\u003cbr\u003eExpert Diagnose=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"YES","marker":{"color":"green","pattern":{"shape":""}},"name":"YES","offsetgroup":"YES","orientation":"v","showlegend":true,"textposition":"auto","x":["Bipolar Type-1","Bipolar Type-2","Depression","Normal"],"xaxis":"x","y":[15,14,10,7],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parc ...
# <div>                            <div id="d4c418a2-dd9d-44ec-bb3e-9fab97700ddc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d4c418a2-dd9d-44ec-bb3e-9fab97700ddc")) {                    Plotly.newPlot(                        "d4c418a2-dd9d-44ec-bb3e-9fab97700ddc",                        [{"alignmentgroup":"True","hovertemplate":"Authority Respect=NO\u003cbr\u003eExpert Diagnose=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"NO","marker":{"color":"red","pattern":{"shape":""}},"name":"NO","offsetgroup":"NO","orientation":"v","showlegend":true,"textposition":"auto","x":["Bipolar Type-1","Bipolar Type-2","Depression","Normal"],"xaxis":"x","y":[22,16,25,10],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Authority Respect=YES\u003cbr\u003eExpert Diagnose=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"YES","marker":{"color":"green","pattern":{"shape":""}},"name":"YES","offsetgroup":"YES","orientation":"v","showlegend":true,"textposition":"auto","x":["Bipolar Type-1","Bipolar Type-2","Depression","Normal"],"xaxis":"x","y":[6,15,6,20],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type ...
# <div>                            <div id="1d720f5a-acd7-470f-8355-8fcf31c081a8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1d720f5a-acd7-470f-8355-8fcf31c081a8")) {                    Plotly.newPlot(                        "1d720f5a-acd7-470f-8355-8fcf31c081a8",                        [{"alignmentgroup":"True","hovertemplate":"Try-Explanation=NO\u003cbr\u003eExpert Diagnose=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"NO","marker":{"color":"red","pattern":{"shape":""}},"name":"NO","offsetgroup":"NO","orientation":"v","showlegend":true,"textposition":"auto","x":["Bipolar Type-1","Bipolar Type-2","Depression","Normal"],"xaxis":"x","y":[13,16,18,16],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Try-Explanation=YES\u003cbr\u003eExpert Diagnose=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"YES","marker":{"color":"green","pattern":{"shape":""}},"name":"YES","offsetgroup":"YES","orientation":"v","showlegend":true,"textposition":"auto","x":["Bipolar Type-1","Bipolar Type-2","Depression","Normal"],"xaxis":"x","y":[15,15,13,14],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type": ...
# <div>                            <div id="1302a098-c0ab-47a1-9dcc-3f745b76208a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1302a098-c0ab-47a1-9dcc-3f745b76208a")) {                    Plotly.newPlot(                        "1302a098-c0ab-47a1-9dcc-3f745b76208a",                        [{"alignmentgroup":"True","hovertemplate":"Aggressive Response=NO\u003cbr\u003eExpert Diagnose=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"NO","marker":{"color":"red","pattern":{"shape":""}},"name":"NO","offsetgroup":"NO","orientation":"v","showlegend":true,"textposition":"auto","x":["Bipolar Type-1","Bipolar Type-2","Depression","Normal"],"xaxis":"x","y":[4,17,22,19],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Aggressive Response=YES\u003cbr\u003eExpert Diagnose=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"YES","marker":{"color":"green","pattern":{"shape":""}},"name":"YES","offsetgroup":"YES","orientation":"v","showlegend":true,"textposition":"auto","x":["Bipolar Type-1","Bipolar Type-2","Depression","Normal"],"xaxis":"x","y":[24,14,9,11],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2}," ...
# <div>                            <div id="9b025045-eabc-4c1d-892f-84643613c2eb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9b025045-eabc-4c1d-892f-84643613c2eb")) {                    Plotly.newPlot(                        "9b025045-eabc-4c1d-892f-84643613c2eb",                        [{"alignmentgroup":"True","hovertemplate":"Ignore & Move-On=NO\u003cbr\u003eExpert Diagnose=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"NO","marker":{"color":"red","pattern":{"shape":""}},"name":"NO","offsetgroup":"NO","orientation":"v","showlegend":true,"textposition":"auto","x":["Bipolar Type-1","Bipolar Type-2","Depression","Normal"],"xaxis":"x","y":[23,17,16,14],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Ignore & Move-On=YES\u003cbr\u003eExpert Diagnose=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"YES","marker":{"color":"green","pattern":{"shape":""}},"name":"YES","offsetgroup":"YES","orientation":"v","showlegend":true,"textposition":"auto","x":["Bipolar Type-1","Bipolar Type-2","Depression","Normal"],"xaxis":"x","y":[5,14,15,16],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type" ...
# <div>                            <div id="e2a29191-c209-40a0-a048-cc94b49c8ce5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e2a29191-c209-40a0-a048-cc94b49c8ce5")) {                    Plotly.newPlot(                        "e2a29191-c209-40a0-a048-cc94b49c8ce5",                        [{"alignmentgroup":"True","hovertemplate":"Nervous Break-down=NO\u003cbr\u003eExpert Diagnose=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"NO","marker":{"color":"red","pattern":{"shape":""}},"name":"NO","offsetgroup":"NO","orientation":"v","showlegend":true,"textposition":"auto","x":["Bipolar Type-1","Bipolar Type-2","Depression","Normal"],"xaxis":"x","y":[12,9,13,24],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Nervous Break-down=YES\u003cbr\u003eExpert Diagnose=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"YES","marker":{"color":"green","pattern":{"shape":""}},"name":"YES","offsetgroup":"YES","orientation":"v","showlegend":true,"textposition":"auto","x":["Bipolar Type-1","Bipolar Type-2","Depression","Normal"],"xaxis":"x","y":[16,22,18,6],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"ty ...
# <div>                            <div id="569c8a7e-02b7-45d5-9606-df9aee6140ee" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("569c8a7e-02b7-45d5-9606-df9aee6140ee")) {                    Plotly.newPlot(                        "569c8a7e-02b7-45d5-9606-df9aee6140ee",                        [{"alignmentgroup":"True","hovertemplate":"Admit Mistakes=NO\u003cbr\u003eExpert Diagnose=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"NO","marker":{"color":"red","pattern":{"shape":""}},"name":"NO","offsetgroup":"NO","orientation":"v","showlegend":true,"textposition":"auto","x":["Bipolar Type-1","Bipolar Type-2","Depression","Normal"],"xaxis":"x","y":[19,16,15,11],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Admit Mistakes=YES\u003cbr\u003eExpert Diagnose=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"YES","marker":{"color":"green","pattern":{"shape":""}},"name":"YES","offsetgroup":"YES","orientation":"v","showlegend":true,"textposition":"auto","x":["Bipolar Type-1","Bipolar Type-2","Depression","Normal"],"xaxis":"x","y":[9,15,16,19],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"sc ...
# <div>                            <div id="88db1c21-f82f-4f3b-9e14-dad52e91c800" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("88db1c21-f82f-4f3b-9e14-dad52e91c800")) {                    Plotly.newPlot(                        "88db1c21-f82f-4f3b-9e14-dad52e91c800",                        [{"alignmentgroup":"True","hovertemplate":"Overthinking=NO\u003cbr\u003eExpert Diagnose=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"NO","marker":{"color":"red","pattern":{"shape":""}},"name":"NO","offsetgroup":"NO","orientation":"v","showlegend":true,"textposition":"auto","x":["Bipolar Type-1","Bipolar Type-2","Depression","Normal"],"xaxis":"x","y":[13,14,8,20],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Overthinking=YES\u003cbr\u003eExpert Diagnose=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"YES","marker":{"color":"green","pattern":{"shape":""}},"name":"YES","offsetgroup":"YES","orientation":"v","showlegend":true,"textposition":"auto","x":["Bipolar Type-1","Bipolar Type-2","Depression","Normal"],"xaxis":"x","y":[15,17,23,10],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatte ...
# <div>                            <div id="74a182c9-6e5e-4477-ba7f-8f15b83cd386" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("74a182c9-6e5e-4477-ba7f-8f15b83cd386")) {                    Plotly.newPlot(                        "74a182c9-6e5e-4477-ba7f-8f15b83cd386",                        [{"coloraxis":"coloraxis","hovertemplate":"Expert Diagnose=%{x}\u003cbr\u003eSadness=%{y}\u003cbr\u003ecount=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","name":"","x":["Bipolar Type-2","Depression","Bipolar Type-1","Bipolar Type-2","Normal","Depression","Bipolar Type-1","Normal","Bipolar Type-2","Depression","Normal","Bipolar Type-1","Bipolar Type-2","Normal","Depression","Bipolar Type-1","Normal","Bipolar Type-1","Depression","Normal","Bipolar Type-2","Bipolar Type-1","Normal","Depression","Bipolar Type-2","Normal","Normal","Depression","Bipolar Type-2","Normal","Bipolar Type-1","Depression","Bipolar Type-2","Bipolar Type-1","Normal","Depression","Bipolar Type-1","Bipolar Type-2","Normal","Bipolar Type-2","Depression","Bipolar Type-2","Normal","Bipolar Type-1","Depression","Bipolar Type-2","Normal","Bipolar Type-2","Bipolar Type-1","Depression","Normal","Bipolar Type-2","Depression","Bipolar Type-1","Bipolar Type-2","Normal","Bipolar Type-1","Bipolar Type-1","Depression","Normal","Bipolar Type-2","Depression","Bipolar Type-1","Bipolar Type-2","Normal","Depression","Normal","Bipolar Type-1","Bipolar Type-2","Bipolar Type-1","Depression","Bipolar Type-2","Bipolar Type-1","Normal","Bipolar Type-2","Depression","Depression","Bipolar Type-2","Normal","Depression","Bipolar Type-1","Bipolar Type-2","Depression","Normal","Bipolar Type-1","Bipolar Type-2","Depression","Bipolar Type-1","Bipolar Type-1","Normal","Depression","Bipolar Type-2","Normal","Bipolar Type-1","Depression","Bipolar Type-2","Bipolar Type-1","Normal","Depression","Bipolar Type-2","Bipolar Type-1","Depression","Bipolar Type-1","Normal","Bipolar Type-2","Depression","Normal","Depression","Bipolar Type-2","Depression","Normal","Bipolar Type-2","Bipolar Type-1","Bipolar Type-2","Normal","Depression","Bipolar Type-1","Bipolar Type-2","Depression","Normal"],"xaxis":"x","xbingroup":"x","y":["Usually","Usually","Sometimes","Usually","Usually","Usually","Seldom","Usually","Most-Often","Usually","Seldom","Seldom","Most-Often","Usually","Usually","Sometimes","Sometimes","Usually","Most-Often","Sometimes","Sometimes","Usually","Sometimes","Usually","Usually","Sometimes","Sometimes","Usually","Usually","Sometimes","Sometimes","Most-Often","Sometimes","Sometimes","Sometimes","Most-Often","Sometimes","Usually","Sometimes","Sometimes","Usually","Most-Often","Seldom","Sometimes","Most-Often","Most-Often","Sometimes","Most-Often","Seldom","Usually","Sometimes","Usually","Most-Often","Seldom","Most-Often","Sometimes","Seldom","Seldom","Sometimes","Seldom","Usually","Usually","Usually","Most-Often","Sometimes","Usually","Sometimes","Sometimes","Usually","Sometimes","Sometimes","Seldom","Sometimes","Sometimes","Usually","Usually","Usually","Usually","Usually","Most-Often","Sometimes","Most-Often","Usually","Seldom","Usually","Sometimes","Usually","Usually","Seldom","Sometimes","Most-Often","Usually","Sometimes","Usually","Most-Often","Usually","Sometimes","Sometimes","Most-Often","Usually","Usually","Sometimes","Seldom","Sometimes","Usually","Most-Often","Seldom","Sometimes","Usually","Most-Often","Sometimes","Sometimes","Seldom","Sometimes","Seldom","Most-Often","Sometimes","Usually","Usually","Sometimes"],"yaxis":"y","ybingroup":"y","type":"histogram2d"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.222222222 ...
# ...
# <div>                            <div id="8a66a548-e721-45d6-b18a-d50ee333b1a9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8a66a548-e721-45d6-b18a-d50ee333b1a9")) {                    Plotly.newPlot(                        "8a66a548-e721-45d6-b18a-d50ee333b1a9",                        [{"coloraxis":"coloraxis","hovertemplate":"Expert Diagnose=%{x}\u003cbr\u003eSexual Activity=%{y}\u003cbr\u003ecount=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","name":"","x":["Bipolar Type-2","Depression","Bipolar Type-1","Bipolar Type-2","Normal","Depression","Bipolar Type-1","Normal","Bipolar Type-2","Depression","Normal","Bipolar Type-1","Bipolar Type-2","Normal","Depression","Bipolar Type-1","Normal","Bipolar Type-1","Depression","Normal","Bipolar Type-2","Bipolar Type-1","Normal","Depression","Bipolar Type-2","Normal","Normal","Depression","Bipolar Type-2","Normal","Bipolar Type-1","Depression","Bipolar Type-2","Bipolar Type-1","Normal","Depression","Bipolar Type-1","Bipolar Type-2","Normal","Bipolar Type-2","Depression","Bipolar Type-2","Normal","Bipolar Type-1","Depression","Bipolar Type-2","Normal","Bipolar Type-2","Bipolar Type-1","Depression","Normal","Bipolar Type-2","Depression","Bipolar Type-1","Bipolar Type-2","Normal","Bipolar Type-1","Bipolar Type-1","Depression","Normal","Bipolar Type-2","Depression","Bipolar Type-1","Bipolar Type-2","Normal","Depression","Normal","Bipolar Type-1","Bipolar Type-2","Bipolar Type-1","Depression","Bipolar Type-2","Bipolar Type-1","Normal","Bipolar Type-2","Depression","Depression","Bipolar Type-2","Normal","Depression","Bipolar Type-1","Bipolar Type-2","Depression","Normal","Bipolar Type-1","Bipolar Type-2","Depression","Bipolar Type-1","Bipolar Type-1","Normal","Depression","Bipolar Type-2","Normal","Bipolar Type-1","Depression","Bipolar Type-2","Bipolar Type-1","Normal","Depression","Bipolar Type-2","Bipolar Type-1","Depression","Bipolar Type-1","Normal","Bipolar Type-2","Depression","Normal","Depression","Bipolar Type-2","Depression","Normal","Bipolar Type-2","Bipolar Type-1","Bipolar Type-2","Normal","Depression","Bipolar Type-1","Bipolar Type-2","Depression","Normal"],"xaxis":"x","xbingroup":"x","y":["3 From 10","4 From 10","6 From 10","3 From 10","5 From 10","3 From 10","7 From 10","5 From 10","8 From 10","3 From 10","5 From 10","8 From 10","9 From 10","5 From 10","5 From 10","6 From 10","5 From 10","6 From 10","3 From 10","4 From 10","6 From 10","6 From 10","3 From 10","4 From 10","4 From 10","6 From 10","3 From 10","5 From 10","2 From 10","5 From 10","3 From 10","4 From 10","5 From 10","6 From 10","5 From 10","2 From 10","8 From 10","4 From 10","5 From 10","3 From 10","8 From 10","2 From 10","4 From 10","8 From 10","4 From 10","4 From 10","4 From 10","4 From 10","5 From 10","4 From 10","4 From 10","3 From 10","2 From 10","5 From 10","2 From 10","3 From 10","5 From 10","7 From 10","3 From 10","5 From 10","4 From 10","4 From 10","7 From 10","4 From 10","5 From 10","3 From 10","7 From 10","8 From 10","7 From 10","5 From 10","2 From 10","5 From 10","7 From 10","6 From 10","3 From 10","7 From 10","8 From 10","2 From 10","6 From 10","6 From 10","8 From 10","2 From 10","5 From 10","7 From 10","7 From 10","2 From 10","4 From 10","9 From 10","6 From 10","7 From 10","4 From 10","2 From 10","5 From 10","7 From 10","2 From 10","1 From 10","5 From 10","6 From 10","3 From 10","2 From 10","8 From 10","1 From 10","6 From 10","7 From 10","2 From 10","3 From 10","6 From 10","8 From 10","2 From 10","3 From 10","4 From 10","4 From 10","8 From 10","1 From 10","5 From 10","2 From 10","6 From 10","1 From 10","7 From 10","7 From 10"],"yaxis":"y","ybingroup":"y","type":"histogram2d"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcon ...
# <div>                            <div id="f7b96867-65f7-4ca2-9c54-60998cc64e68" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f7b96867-65f7-4ca2-9c54-60998cc64e68")) {                    Plotly.newPlot(                        "f7b96867-65f7-4ca2-9c54-60998cc64e68",                        [{"coloraxis":"coloraxis","hovertemplate":"Expert Diagnose=%{x}\u003cbr\u003eConcentration=%{y}\u003cbr\u003ecount=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","name":"","x":["Bipolar Type-2","Depression","Bipolar Type-1","Bipolar Type-2","Normal","Depression","Bipolar Type-1","Normal","Bipolar Type-2","Depression","Normal","Bipolar Type-1","Bipolar Type-2","Normal","Depression","Bipolar Type-1","Normal","Bipolar Type-1","Depression","Normal","Bipolar Type-2","Bipolar Type-1","Normal","Depression","Bipolar Type-2","Normal","Normal","Depression","Bipolar Type-2","Normal","Bipolar Type-1","Depression","Bipolar Type-2","Bipolar Type-1","Normal","Depression","Bipolar Type-1","Bipolar Type-2","Normal","Bipolar Type-2","Depression","Bipolar Type-2","Normal","Bipolar Type-1","Depression","Bipolar Type-2","Normal","Bipolar Type-2","Bipolar Type-1","Depression","Normal","Bipolar Type-2","Depression","Bipolar Type-1","Bipolar Type-2","Normal","Bipolar Type-1","Bipolar Type-1","Depression","Normal","Bipolar Type-2","Depression","Bipolar Type-1","Bipolar Type-2","Normal","Depression","Normal","Bipolar Type-1","Bipolar Type-2","Bipolar Type-1","Depression","Bipolar Type-2","Bipolar Type-1","Normal","Bipolar Type-2","Depression","Depression","Bipolar Type-2","Normal","Depression","Bipolar Type-1","Bipolar Type-2","Depression","Normal","Bipolar Type-1","Bipolar Type-2","Depression","Bipolar Type-1","Bipolar Type-1","Normal","Depression","Bipolar Type-2","Normal","Bipolar Type-1","Depression","Bipolar Type-2","Bipolar Type-1","Normal","Depression","Bipolar Type-2","Bipolar Type-1","Depression","Bipolar Type-1","Normal","Bipolar Type-2","Depression","Normal","Depression","Bipolar Type-2","Depression","Normal","Bipolar Type-2","Bipolar Type-1","Bipolar Type-2","Normal","Depression","Bipolar Type-1","Bipolar Type-2","Depression","Normal"],"xaxis":"x","xbingroup":"x","y":["3 From 10","2 From 10","5 From 10","2 From 10","5 From 10","5 From 10","2 From 10","5 From 10","2 From 10","4 From 10","7 From 10","4 From 10","2 From 10","7 From 10","4 From 10","4 From 10","4 From 10","2 From 10","4 From 10","4 From 10","2 From 10","4 From 10","7 From 10","4 From 10","4 From 10","6 From 10","4 From 10","2 From 10","2 From 10","5 From 10","2 From 10","4 From 10","5 From 10","5 From 10","5 From 10","4 From 10","5 From 10","3 From 10","5 From 10","3 From 10","2 From 10","2 From 10","4 From 10","2 From 10","3 From 10","4 From 10","5 From 10","3 From 10","4 From 10","4 From 10","4 From 10","3 From 10","2 From 10","1 From 10","2 From 10","4 From 10","4 From 10","2 From 10","7 From 10","4 From 10","4 From 10","5 From 10","4 From 10","4 From 10","6 From 10","5 From 10","6 From 10","4 From 10","5 From 10","4 From 10","6 From 10","3 From 10","5 From 10","4 From 10","7 From 10","3 From 10","2 From 10","2 From 10","6 From 10","3 From 10","2 From 10","4 From 10","7 From 10","8 From 10","6 From 10","4 From 10","7 From 10","2 From 10","6 From 10","3 From 10","4 From 10","6 From 10","7 From 10","1 From 10","8 From 10","4 From 10","5 From 10","2 From 10","7 From 10","5 From 10","1 From 10","6 From 10","6 From 10","4 From 10","4 From 10","7 From 10","5 From 10","7 From 10","1 From 10","3 From 10","7 From 10","1 From 10","8 From 10","5 From 10","8 From 10","5 From 10","7 From 10","5 From 10","7 From 10","3 From 10"],"yaxis":"y","ybingroup":"y","type":"histogram2d"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dconto ...
# <div>                            <div id="8c82881a-f2d0-4218-a393-46b97c23d870" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8c82881a-f2d0-4218-a393-46b97c23d870")) {                    Plotly.newPlot(                        "8c82881a-f2d0-4218-a393-46b97c23d870",                        [{"coloraxis":"coloraxis","hovertemplate":"Expert Diagnose=%{x}\u003cbr\u003eOptimisim=%{y}\u003cbr\u003ecount=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","name":"","x":["Bipolar Type-2","Depression","Bipolar Type-1","Bipolar Type-2","Normal","Depression","Bipolar Type-1","Normal","Bipolar Type-2","Depression","Normal","Bipolar Type-1","Bipolar Type-2","Normal","Depression","Bipolar Type-1","Normal","Bipolar Type-1","Depression","Normal","Bipolar Type-2","Bipolar Type-1","Normal","Depression","Bipolar Type-2","Normal","Normal","Depression","Bipolar Type-2","Normal","Bipolar Type-1","Depression","Bipolar Type-2","Bipolar Type-1","Normal","Depression","Bipolar Type-1","Bipolar Type-2","Normal","Bipolar Type-2","Depression","Bipolar Type-2","Normal","Bipolar Type-1","Depression","Bipolar Type-2","Normal","Bipolar Type-2","Bipolar Type-1","Depression","Normal","Bipolar Type-2","Depression","Bipolar Type-1","Bipolar Type-2","Normal","Bipolar Type-1","Bipolar Type-1","Depression","Normal","Bipolar Type-2","Depression","Bipolar Type-1","Bipolar Type-2","Normal","Depression","Normal","Bipolar Type-1","Bipolar Type-2","Bipolar Type-1","Depression","Bipolar Type-2","Bipolar Type-1","Normal","Bipolar Type-2","Depression","Depression","Bipolar Type-2","Normal","Depression","Bipolar Type-1","Bipolar Type-2","Depression","Normal","Bipolar Type-1","Bipolar Type-2","Depression","Bipolar Type-1","Bipolar Type-1","Normal","Depression","Bipolar Type-2","Normal","Bipolar Type-1","Depression","Bipolar Type-2","Bipolar Type-1","Normal","Depression","Bipolar Type-2","Bipolar Type-1","Depression","Bipolar Type-1","Normal","Bipolar Type-2","Depression","Normal","Depression","Bipolar Type-2","Depression","Normal","Bipolar Type-2","Bipolar Type-1","Bipolar Type-2","Normal","Depression","Bipolar Type-1","Bipolar Type-2","Depression","Normal"],"xaxis":"x","xbingroup":"x","y":["4 From 10","5 From 10","7 From 10","2 From 10","6 From 10","5 From 10","9 From 10","5 From 10","3 From 10","2 From 10","8 From 10","9 From 10","4 From 10","5 From 10","2 From 10","6 From 10","6 From 10","3 From 10","1 From 10","6 From 10","3 From 10","6 From 10","6 From 10","2 From 10","3 From 10","5 From 10","2 From 10","4 From 10","3 From 10","5 From 10","6 From 10","3 From 10","4 From 10","4 From 10","6 From 10","4 From 10","5 From 10","4 From 10","3 From 10","2 From 10","2 From 10","2 From 10","6 From 10","8 From 10","3 From 10","4 From 10","5 From 10","6 From 10","6 From 10","3 From 10","6 From 10","3 From 10","2 From 10","4 From 10","1 From 10","3 From 10","6 From 10","2 From 10","4 From 10","4 From 10","3 From 10","2 From 10","6 From 10","4 From 10","5 From 10","2 From 10","6 From 10","5 From 10","4 From 10","6 From 10","2 From 10","5 From 10","7 From 10","5 From 10","4 From 10","2 From 10","8 From 10","4 From 10","6 From 10","3 From 10","6 From 10","5 From 10","4 From 10","6 From 10","7 From 10","1 From 10","2 From 10","8 From 10","7 From 10","5 From 10","3 From 10","4 From 10","6 From 10","7 From 10","4 From 10","5 From 10","8 From 10","6 From 10","2 From 10","2 From 10","8 From 10","3 From 10","5 From 10","5 From 10","4 From 10","1 From 10","7 From 10","5 From 10","1 From 10","3 From 10","5 From 10","2 From 10","5 From 10","1 From 10","7 From 10","3 From 10","8 From 10","3 From 10","7 From 10","8 From 10"],"yaxis":"y","ybingroup":"y","type":"histogram2d"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour", ...

# %%
# We have catogorical features, so we need to encode them

from sklearn.preprocessing import LabelEncoder
encoders={} 
for i in df.columns[:-1]:
    encoders[i]=LabelEncoder() # define individual encoder for each column
    encoders[i].fit(df[i])
    df[i]=encoders[i].transform(df[i])

# %%
# Selecting best features in order to increase model's performance

from sklearn.feature_selection import mutual_info_classif
feature_selection=SelectKBest(score_func=mutual_info_classif)
feature_selection=feature_selection.fit(df[df.columns[:-1]],df[df.columns[-1]])

features_scores=pd.Series(feature_selection.scores_,df.columns[:-1])
features_scores.nlargest(18).plot(kind='barh',title="features' scores")
plt.show()

# %%
# defining train and test set
x_train,x_test,y_train,y_test=train_test_split(df[features_scores.nlargest(5).index],df[df.columns[-1]],test_size=0.3,random_state=2,shuffle=True)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier


param_grid = {
    'bootstrap': [True],
    'max_depth': [120],
    'max_features': [2, 3],
    'min_samples_leaf': [3, 4],
    'min_samples_split': [ 10, 12],
    'n_estimators': [ 300, 1000]
}

# Create a based model
model = RandomForestClassifier()
# Instantiate the grid search model
grid_search = GridSearchCV(estimator = model, param_grid = param_grid, cv = 3, n_jobs = -1, verbose = 2,scoring='accuracy')

grid_search.fit(x_train, y_train)
# Out:
# Fitting 3 folds for each of 16 candidates, totalling 48 fits
# GridSearchCV(cv=3, estimator=RandomForestClassifier(), n_jobs=-1,
#              param_grid={'bootstrap': [True], 'max_depth': [120],
#                          'max_features': [2, 3], 'min_samples_leaf': [3, 4],
#                          'min_samples_split': [10, 12],
#                          'n_estimators': [300, 1000]},
#              scoring='accuracy', verbose=2)

# %%
# best parameters for model
grid_search.best_params_
# Out:
# {'bootstrap': True,
#  'max_depth': 120,
#  'max_features': 2,
#  'min_samples_leaf': 3,
#  'min_samples_split': 10,
#  'n_estimators': 300}

# %%
y_predict=grid_search.predict(x_test)
print(classification_report(y_test,y_predict))
# Out:
#                 precision    recall  f1-score   support
#
# Bipolar Type-1       1.00      0.88      0.93         8
# Bipolar Type-2       0.91      1.00      0.95        10
#     Depression       0.80      1.00      0.89         8
#         Normal       1.00      0.80      0.89        10
#
#       accuracy                           0.92        36
#      macro avg       0.93      0.92      0.92        36
#   weighted avg       0.93      0.92      0.92        36
